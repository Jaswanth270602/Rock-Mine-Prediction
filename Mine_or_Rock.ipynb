# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaswanth270602/Rock-Mine-Prediction/blob/main/Mine_or_Rock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
sonar_data = pd.read_csv('/content/Copy of sonar data.csv',header=None)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
sonar_data.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
x = sonar_data.drop(columns=60,axis=1)
y = sonar_data[60]

# %%
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: 60, Length: 208, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify=y,random_state=1)

# %%
x_train.head()
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 183  0.0096  0.0404  0.0682  0.0688  0.0887  0.0932  0.0955  0.2140  0.2546
# 27   0.0177  0.0300  0.0288  0.0394  0.0630  0.0526  0.0688  0.0633  0.0624
# 149  0.0207  0.0535  0.0334  0.0818  0.0740  0.0324  0.0918  0.1070  0.1553
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 94   0.0025  0.0309  0.0171  0.0228  0.0434  0.1224  0.1947  0.1661  0.1368
#
#          9   ...      50      51      52      53      54      55      56  \
# 183  0.2952  ...  0.0310  0.0237  0.0078  0.0144  0.0170  0.0012  0.0109
# 27   0.0613  ...  0.0168  0.0102  0.0122  0.0044  0.0075  0.0124  0.0099
# 149  0.1234  ...  0.0171  0.0033  0.0050  0.0190  0.0103  0.0121  0.0042
# 4    0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
# 94   0.1430  ...  0.0108  0.0149  0.0077  0.0036  0.0114  0.0085  0.0101
#
#          57      58      59
# 183  0.0036  0.0043  0.0018
# ...

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_train_pred = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_pred,y_train)
training_data_accuracy
# Out:
# 0.8433734939759037

# %%
x_test_pred = model.predict(x_test)
testing_data_accuracy = accuracy_score(x_test_pred,y_test)
testing_data_accuracy
# Out:
# 0.6904761904761905

# %%
input_data = (0.0307,0.0523,0.0653,0.0521,0.0611,0.0577,0.0665,0.0664,0.1460,0.2792,0.3877,0.4992,0.4981,0.4972,0.5607,0.7339,0.8230,0.9173,0.9975,0.9911,0.8240,0.6498,0.5980,0.4862,0.3150,0.1543,0.0989,0.0284,0.1008,0.2636,0.2694,0.2930,0.2925,0.3998,0.3660,0.3172,0.4609,0.4374,0.1820,0.3376,0.6202,0.4448,0.1863,0.1420,0.0589,0.0576,0.0672,0.0269,0.0245,0.0190,0.0063,0.0321,0.0189,0.0137,0.0277,0.0152,0.0052,0.0121,0.0124,0.0055)
input_data_as_array = np.asarray(input_data)
input_data_reshaped = input_data_as_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
if(prediction == 'M'):
  res="This is a Mine , Beware of it"
else:
  res="This is just a Rock , carry on"

res
# Out:
# 'This is a Mine , Beware of it'

# %%
plt.figure(figsize=(8,5))

# %%
# Training data
plt.subplot(1, 2, 1)
plt.scatter(x_train_pred, y_train, color='blue', label='Training Data')
plt.plot(x_train_pred, y_train, color='gray')
plt.xlabel('X Train Predictions')
plt.ylabel('Y Train')
plt.title('Training Data')
plt.legend()

# Testing Data
plt.subplot(1, 2, 2)
plt.scatter(x_test_pred, y_test, color="red", label= "Testing Data")
plt.plot(x_test_pred, y_test, color="gray")
plt.xlabel('X Test Predictions')
plt.ylabel('Y test')
plt.title('Testing Data')
plt.legend()

plt.tight_layout()
plt.show()

# %%
res
# Out:
# 'This is a Mine , Beware of it'
